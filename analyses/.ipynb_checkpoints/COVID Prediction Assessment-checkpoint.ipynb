# %% [markdown]
# # COVID Prediction Assessment
#
# We don't spend enough time assessing. Let's take a look at the great data provided by the CDC: https://www.cdc.gov/coronavirus/2019-ncov/covid-data/forecasting-us-cases-previous.html

# %%
import requests
import os
import pandas as pd

# %%
link = "https://www.cdc.gov/coronavirus/2019-ncov/downloads/cases-updates/2020-11-16-national-forecasted-cases-model-data.xlsx"
data_20201116 = pd.read_excel(io = link, sheet_name = "individual_models")

# %%
data_20201116.head()
# Out:
#       model forecast_date               target target_end_date location_name  \
# 0   JHU-IDD    2020-11-16  1 wk ahead inc case      2020-11-21      National
# 1   BPagano    2020-11-16  1 wk ahead inc case      2020-11-21      National
# 2  JHU-CSSE    2020-11-16  1 wk ahead inc case      2020-11-21      National
# 3    Karlen    2020-11-16  1 wk ahead inc case      2020-11-21      National
# 4       USC    2020-11-16  1 wk ahead inc case      2020-11-21      National
#
#       State fips    point  quantile_0.025  quantile_0.25  quantile_0.75  \
# 0  National   US   745599          599518         681861         804607
# 1  National   US  1203810          733238        1038281        1362080
# 2  National   US  1167623          694922        1006244        1311958
# 3  National   US  1212974         1093942        1160965        1229478
# 4  National   US   984428          254087         772301        1263096
#
#    quantile_0.975
# 0          939852
# 1         1667122
# ...
